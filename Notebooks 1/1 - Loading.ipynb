# %% [markdown]
# # **1: Loading**

# %% [markdown]
# ## Import Libraries

# %%
from sqlalchemy import create_engine, text
import csv
import pandas as pd

# %% [markdown]
# ## Connect to Database

# %%
engine = create_engine('postgresql://bryguan:qwertyuiop@localhost:5432/acme')
connection = engine.connect().execution_options(auto_commit = True)

# %% [markdown]
# ## Drop Existing Tables

# %% [markdown]
# ### Cities

# %%
query = '''

DROP TABLE IF EXISTS cities_1;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Customers

# %%
query = '''

DROP TABLE IF EXISTS customers_1;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Holidays

# %%
query = '''

DROP TABLE IF EXISTS holidays_1;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Line Items

# %%
query = '''

DROP TABLE IF EXISTS line_items_1;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Products

# %%
query = '''

DROP TABLE IF EXISTS products_1;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Sales

# %%
query = '''

DROP TABLE IF EXISTS sales_1;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### States

# %%
query = '''

DROP TABLE IF EXISTS states_1;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Stores

# %%
query = '''

DROP TABLE IF EXISTS stores_1;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### ZIP Codes

# %%
query = '''

DROP TABLE IF EXISTS zip_codes_1;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ## Create Staging Tables

# %% [markdown]
# ### Cities

# %%
with open('/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/cities_1.csv') as file:
    cities = list(csv.reader(file))
    for city in cities[:5]:
        print(city)
# Out:
# ['city', 'state', 'latitude', 'longitude', 'population', 'area', 'density', 'time_zone']
# ['Aaronsburg', 'PA', '40.8956', '-77.3924', '1030.0', '23.9569', '42.99', 'America/New_York']
# ['Abbeville', 'AL', '31.603', '-85.2163', '6055.0', '191.6269', '31.6', 'America/Chicago']
# ['Abbeville', 'GA', '31.9755', '-83.3407', '4563.0', '166.206', '27.45', 'America/New_York']
# ['Abbeville', 'LA', '29.8981', '-92.1997', '25897.0', '235.8227', '109.82', 'America/Chicago']

# %%
query = '''

CREATE TABLE cities_1 (
    city varchar(50),
    state char(2),
    latitude numeric(10, 5),
    longitude numeric(10, 5),
    population numeric(10),
    area numeric(20, 5),
    density numeric(20, 5),
    time_zone varchar(50),
    PRIMARY KEY (city, state)
)

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Customers

# %%
with open('/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/customers_1.csv') as file:
    customers = list(csv.reader(file))
    for customer in customers[:5]:
        print(customer)
# Out:
# ['customer_id', 'first_name', 'last_name', 'street', 'city', 'state', 'zip', 'closest_store_id', 'distance']
# ['1.0', 'Robb', 'Weaving', '5 Ramsey Place', 'Oakland', 'CA', '94609', '1.0', '1.0']
# ['2.0', 'Robby', 'Belliard', '6 Londonderry Plaza', 'Oakland', 'CA', '94609', '1.0', '1.0']
# ['3.0', 'Sadella', 'Caudrelier', '548 Mcguire Parkway', 'Oakland', 'CA', '94609', '1.0', '1.0']
# ['4.0', 'Holmes', 'Shimmings', '99 Kennedy Court', 'Oakland', 'CA', '94609', '1.0', '1.0']

# %%
query = '''

CREATE TABLE customers_1 (
    customer_id numeric(5) PRIMARY KEY,
    first_name varchar(25),
    last_name varchar(25),
    street varchar(50),
    city varchar(50),
    state char(2),
    zip_code char(5),
    store_id numeric(5),
    distance numeric(5)
)

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Holidays

# %%
with open('/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/holidays_1.csv') as file:
    holidays = list(csv.reader(file))
    for holiday in holidays[:5]:
        print(holiday)
# Out:
# ['holiday_date', 'description', 'closed_flag']
# ['2020-01-01', "New Year's Day", 'False']
# ['2020-01-20', 'MLK Day', 'False']
# ['2020-02-17', "President's Day", 'False']
# ['2020-04-12', 'Easter', 'False']

# %%
query = '''

CREATE TABLE holidays_1 (
    date date PRIMARY KEY,
    description varchar(25),
    closed boolean
)

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Line Items

# %%
with open('/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/line_items_1.csv') as file:
    line_items = list(csv.reader(file))
    for line_item in line_items[:5]:
        print(line_item)
# Out:
# ['store_id', 'sale_id', 'line_item_id', 'product_id', 'quantity']
# ['1.0', '1.0', '1.0', '1.0', '2.0']
# ['1.0', '1.0', '2.0', '2.0', '2.0']
# ['1.0', '2.0', '1.0', '1.0', '4.0']
# ['1.0', '2.0', '2.0', '3.0', '2.0']

# %%
query = '''

CREATE TABLE line_items_1 (
    store_id numeric(5),
    sale_id numeric(10),
    line_item_id numeric(5),
    product_id numeric(5),
    quantity numeric(5),
    PRIMARY KEY (store_id, sale_id, line_item_id)
)

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Products

# %%
with open('/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/products_1.csv') as file:
    products = list(csv.reader(file))
    for product in products[:5]:
        print(product)
# Out:
# ['product_id', 'description']
# ['1.0', 'Pistachio Salmon']
# ['2.0', 'Teriyaki Chicken']
# ['3.0', 'Spinach Orzo']
# ['4.0', 'Eggplant Lasagna']

# %%
query = '''

CREATE TABLE products_1 (
    product_id numeric(5) PRIMARY KEY,
    description varchar(25)
)

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Sales

# %%
with open('/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/sales_1.csv') as file:
    sales = list(csv.reader(file))
    for sale in sales[:5]:
        print(sale)
# Out:
# ['store_id', 'sale_id', 'customer_id', 'sale_date', 'total_amount']
# ['1.0', '1.0', '710.0', '2020-01-01', '48.0']
# ['1.0', '2.0', '1477.0', '2020-01-01', '132.0']
# ['1.0', '3.0', '1820.0', '2020-01-01', '48.0']
# ['1.0', '4.0', '1272.0', '2020-01-01', '96.0']

# %%
query = '''

CREATE TABLE sales_1 (
    store_id numeric(5),
    sale_id numeric(10),
    customer_id numeric(5),
    date date,
    total numeric(5),
    PRIMARY KEY (store_id, sale_id)
)

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### States

# %%
with open('/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/states_1.csv') as file:
    states = list(csv.reader(file))
    for state in states[:5]:
        print(state)
# Out:
# ['state', 'state_name', 'latitude', 'longitude', 'population', 'area', 'density']
# ['PA', 'Pennsylvania', '40.9479', '-77.628', '12790950.0', '43851.7864', '291.69']
# ['OH', 'Ohio', '40.1758', '-82.6609', '11639989.0', '40511.7523', '287.32']
# ['TN', 'Tennessee', '35.8113', '-85.9375', '6644470.0', '41397.0517', '160.51']
# ['MS', 'Mississippi', '32.6082', '-89.7987', '2988710.0', '45241.4545', '66.06']

# %%
query = '''

CREATE TABLE states_1 (
    state char(2) PRIMARY KEY,
    name varchar(25),
    latitude numeric(10, 5),
    longitude numeric(10, 5),
    population numeric(10),
    area numeric(20, 5),
    density numeric(20, 5)
)

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Stores

# %%
with open('/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/stores_1.csv') as file:
    stores = list(csv.reader(file))
    for store in stores[:5]:
        print(store)
# Out:
# ['store_id', 'street', 'city', 'state', 'zip', 'latitude', 'longitude']
# ['1.0', '3000 Telegraph Ave', 'Berkeley', 'CA', '94705', '37.8555', '-122.2604']
# ['2.0', '1001 Broadway', 'Seattle', 'WA', '98122', '47.6114', '-122.3214']
# ['3.0', '2510 McKinney Ave', 'Dallas', 'TX', '75201', '32.7958', '-96.8015']
# ['4.0', '299 SE 3rd Ave', 'Miami', 'FL', '33131', '25.772', '-80.1891']

# %%
query = '''

CREATE TABLE stores_1 (
    store_id numeric(5) PRIMARY KEY,
    street varchar(50),
    city varchar(50),
    state char(2),
    zip_code char(5),
    latitude numeric(10, 5),
    longitude numeric(10, 5)
)

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### ZIP Codes

# %%
with open('/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/zip_codes_1.csv') as file:
    zip_codes = list(csv.reader(file))
    for zip_code in zip_codes[:5]:
        print(zip_code)
# Out:
# ['zip', 'latitude', 'longitude', 'city', 'state', 'population', 'area', 'density', 'time_zone']
# ['08074', '39.7158', '-75.164', 'Richwood', 'NJ', '15.0', '0.0886', '169.39', 'America/New_York']
# ['08240', '39.4873', '-74.5318', 'Pomona', 'NJ', '2293.0', '1.5196', '1508.93', 'America/New_York']
# ['08876', '40.588', '-74.6874', 'Somerville', 'NJ', '22059.0', '15.1172', '1459.2', 'America/New_York']
# ['10001', '40.7506', '-73.9972', 'New York', 'NY', '22924.0', '0.6675', '34341.44', 'America/New_York']

# %%
query = '''

CREATE TABLE zip_codes_1 (
    zip_code char(5) PRIMARY KEY,
    latitude numeric(10, 5),
    longitude numeric(10, 5),
    city varchar(50),
    state char(2),
    population numeric(10),
    area numeric(20, 5),
    density numeric(20, 5),
    time_zone varchar(50)
)

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ## Load

# %% [markdown]
# ### Cities

# %%
query = '''

COPY cities_1 (city, state, latitude, longitude, population, area, density, time_zone)
FROM '/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/cities_1.csv'
DELIMITER ','
CSV HEADER;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Customers

# %%
query = '''

COPY customers_1 (customer_id, first_name, last_name, street, city, state, zip_code, store_id, distance)
FROM '/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/customers_1.csv'
DELIMITER ','
CSV HEADER;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Holidays

# %%
query = '''

COPY holidays_1 (date, description, closed)
FROM '/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/holidays_1.csv'
DELIMITER ','
CSV HEADER;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Line Items

# %%
query = '''

COPY line_items_1 (store_id, sale_id, line_item_id, product_id, quantity)
FROM '/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/line_items_1.csv'
DELIMITER ','
CSV HEADER;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Products

# %%
query = '''

COPY products_1 (product_id, description)
FROM '/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/products_1.csv'
DELIMITER ','
CSV HEADER;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Sales

# %%
query = '''

COPY sales_1 (store_id, sale_id, customer_id, date, total)
FROM '/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/sales_1.csv'
DELIMITER ','
CSV HEADER;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### States

# %%
query = '''

COPY states_1 (state, name, latitude, longitude, population, area, density)
FROM '/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/states_1.csv'
DELIMITER ','
CSV HEADER;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### Stores

# %%
query = '''

COPY stores_1 (store_id, street, city, state, zip_code, latitude, longitude)
FROM '/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/stores_1.csv'
DELIMITER ','
CSV HEADER;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ### ZIP Codes

# %%
query = '''

COPY zip_codes_1 (zip_code, latitude, longitude, city, state, population, area, density, time_zone)
FROM '/Users/bryguan/Documents/GitHub/acme-sales-analysis/Data 1/zip_codes_1.csv'
DELIMITER ','
CSV HEADER;

'''

try:
    with connection.begin():
        connection.execute(text(query))
except Exception as e:
    print(f' Error {e}')

# %% [markdown]
# ## Verify Load

# %% [markdown]
# ### Cities

# %%
query = '''

SELECT *
FROM cities_1;

'''

display(pd.read_sql_query(query, connection))
# Out:
#              city state  latitude  longitude  population      area  density  \
# 0      Aaronsburg    PA   40.8956   -77.3924      1030.0   23.9569    42.99
# 1       Abbeville    AL   31.6030   -85.2163      6055.0  191.6269    31.60
# 2       Abbeville    GA   31.9755   -83.3407      4563.0  166.2060    27.45
# 3       Abbeville    LA   29.8981   -92.1997     25897.0  235.8227   109.82
# 4       Abbeville    MS   34.4820   -89.4397      2221.0   90.2666    24.60
# ...           ...   ...       ...        ...         ...       ...      ...
# 27415        Zuni    NM   34.9802  -108.7882      9560.0  696.4406    13.73
# 27416        Zuni    VA   36.8273   -76.8560      2104.0   46.9571    44.81
# 27417      Zurich    MT   48.6571  -109.0158        63.0   48.6489     1.29
# 27418     Zwingle    IA   42.2855   -90.7162       870.0   65.8645    13.21
# 27419      Zwolle    LA   31.6493   -93.6182      5344.0  109.7515    48.69
#
#               time_zone
# 0      America/New_York
# ...

# %% [markdown]
# ### Customers

# %%
query = '''

SELECT *
FROM customers_1;

'''

display(pd.read_sql_query(query, connection))
# Out:
#        customer_id first_name   last_name                 street  \
# 0              1.0       Robb     Weaving         5 Ramsey Place
# 1              2.0      Robby    Belliard    6 Londonderry Plaza
# 2              3.0    Sadella  Caudrelier    548 Mcguire Parkway
# 3              4.0     Holmes   Shimmings       99 Kennedy Court
# 4              5.0   Beverley      Gubbin       51 Mcbride Drive
# ...            ...        ...         ...                    ...
# 31077      31078.0       Hugo     Domeney          529 5th Plaza
# 31078      31079.0      Glenn      Putson  1347 Westend Crossing
# 31079      31080.0     Minnie      Antham           9 Judy Place
# 31080      31081.0      Linet     Djorvic     29 Trailsway Drive
# 31081      31082.0     Randal     Bourdas  2 Crescent Oaks Drive
#
#                     city state zip_code  store_id  distance
# 0                Oakland    CA    94609       1.0       1.0
# 1                Oakland    CA    94609       1.0       1.0
# ...

# %% [markdown]
# ### Holidays

# %%
query = '''

SELECT *
FROM holidays_1;

'''

display(pd.read_sql_query(query, connection))
# Out:
#           date       description  closed
# 0   2020-01-01    New Year's Day   False
# 1   2020-01-20           MLK Day   False
# 2   2020-02-17   President's Day   False
# 3   2020-04-12            Easter   False
# 4   2020-05-10      Mother's Day   False
# 5   2020-05-25      Memorial Day   False
# 6   2020-06-21      Father's Day   False
# 7   2020-07-04  Independence Day   False
# 8   2020-09-07         Labor Day   False
# 9   2020-11-11     Veterans Days   False
# 10  2020-11-26      Thanksgiving    True
# 11  2020-12-25         Christmas    True

# %% [markdown]
# ### Line Items

# %%
query = '''

SELECT *
FROM line_items_1;

'''

display(pd.read_sql_query(query, connection))
# Out:
#          store_id   sale_id  line_item_id  product_id  quantity
# 0             1.0       1.0           1.0         1.0       2.0
# 1             1.0       1.0           2.0         2.0       2.0
# 2             1.0       2.0           1.0         1.0       4.0
# 3             1.0       2.0           2.0         3.0       2.0
# 4             1.0       2.0           3.0         4.0       1.0
# ...           ...       ...           ...         ...       ...
# 5417969       5.0  227721.0           2.0         2.0       1.0
# 5417970       5.0  227721.0           3.0         3.0       1.0
# 5417971       5.0  227721.0           4.0         5.0       1.0
# 5417972       5.0  227721.0           5.0         6.0       1.0
# 5417973       5.0  227721.0           6.0         8.0       1.0
#
# [5417974 rows x 5 columns]

# %% [markdown]
# ### Products

# %%
query = '''

SELECT *
FROM products_1;

'''

display(pd.read_sql_query(query, connection))
# Out:
#    product_id        description
# 0         1.0   Pistachio Salmon
# 1         2.0   Teriyaki Chicken
# 2         3.0       Spinach Orzo
# 3         4.0   Eggplant Lasagna
# 4         5.0      Chicken Salad
# 5         6.0      Curry Chicken
# 6         7.0    Tilapia Piccata
# 7         8.0  Brocolli Stir Fry

# %% [markdown]
# ### Sales

# %%
query = '''

SELECT *
FROM sales_1;

'''

display(pd.read_sql_query(query, connection))
# Out:
#          store_id   sale_id  customer_id        date  total
# 0             1.0       1.0        710.0  2020-01-01   48.0
# 1             1.0       2.0       1477.0  2020-01-01  132.0
# 2             1.0       3.0       1820.0  2020-01-01   48.0
# 3             1.0       4.0       1272.0  2020-01-01   96.0
# 4             1.0       5.0       1986.0  2020-01-01   36.0
# ...           ...       ...          ...         ...    ...
# 1537612       5.0  227717.0      29429.0  2020-12-31   60.0
# 1537613       5.0  227718.0      31048.0  2020-12-31   96.0
# 1537614       5.0  227719.0      30206.0  2020-12-31   60.0
# 1537615       5.0  227720.0      29097.0  2020-12-31   12.0
# 1537616       5.0  227721.0      31033.0  2020-12-31   72.0
#
# [1537617 rows x 5 columns]

# %% [markdown]
# ### States

# %%
query = '''

SELECT *
FROM states_1;

'''

display(pd.read_sql_query(query, connection))
# Out:
#    state                  name  latitude  longitude  population         area  \
# 0     PA          Pennsylvania   40.9479   -77.6280  12790950.0   43851.7864
# 1     OH                  Ohio   40.1758   -82.6609  11639989.0   40511.7523
# 2     TN             Tennessee   35.8113   -85.9375   6644470.0   41397.0517
# 3     MS           Mississippi   32.6082   -89.7987   2988710.0   45241.4545
# 4     CT           Connecticut   41.5278   -72.7300   3581504.0    4791.4988
# 5     NM            New Mexico   34.3614  -106.0363   2089364.0   93194.3046
# 6     WV         West Virginia   38.9190   -80.1741   1828786.0   23062.9882
# 7     KS                Kansas   38.4942   -98.3132   2908448.0   80002.7898
# 8     HI                Hawaii   20.6370  -157.5532   1422019.0    5832.0637
# 9     IA                  Iowa   41.9628   -93.3776   3133061.0   55067.8240
# 10    KY              Kentucky   37.8153   -85.6432   4446667.0   38715.1258
# ...

# %% [markdown]
# ### Stores

# %%
query = '''

SELECT *
FROM stores_1;

'''

display(pd.read_sql_query(query, connection))
# Out:
#    store_id              street       city state zip_code  latitude  longitude
# 0       1.0  3000 Telegraph Ave   Berkeley    CA    94705   37.8555  -122.2604
# 1       2.0       1001 Broadway    Seattle    WA    98122   47.6114  -122.3214
# 2       3.0   2510 McKinney Ave     Dallas    TX    75201   32.7958   -96.8015
# 3       4.0      299 SE 3rd Ave      Miami    FL    33131   25.7720   -80.1891
# 4       5.0       1202 Broadway  Nashville    TN    37203   36.1568   -86.7881

# %% [markdown]
# ### ZIP Codes

# %%
query = '''

SELECT *
FROM zip_codes_1;

'''

display(pd.read_sql_query(query, connection))
# Out:
#       zip_code  latitude  longitude        city state  population     area  \
# 0        08074   39.7158   -75.1640    Richwood    NJ        15.0   0.0886
# 1        08240   39.4873   -74.5318      Pomona    NJ      2293.0   1.5196
# 2        08876   40.5880   -74.6874  Somerville    NJ     22059.0  15.1172
# 3        10001   40.7506   -73.9972    New York    NY     22924.0   0.6675
# 4        32026   30.0541   -82.1815     Raiford    FL      1907.0   0.6333
# ...        ...       ...        ...         ...   ...         ...      ...
# 32718    47367   40.0827   -85.3872    Oakville    IN        23.0   0.0866
# 32719    63079   38.2606   -91.0998     Stanton    MO        24.0   0.3523
# 32720    63738   37.0893   -89.9574   Brownwood    MO        31.0   0.1171
# 32721    68954   40.6227   -98.2374      Inland    NE        14.0   1.7437
# 32722    72377   35.6876   -90.3385   Rivervale    AR         9.0   0.1931
#
#         density                     time_zone
# ...

# %% [markdown]
# ## Close Connection

# %%
connection.close()
engine.dispose()
